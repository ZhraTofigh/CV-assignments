# %% [markdown]
# ### **install**

# %%
# !pip install numpy matplotlib opencv-python

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt
import os

# %% [markdown]
# ### **numpy**

# %% [markdown]
# create an array

# %%
array_2d = np.array([[10, 20, 30],
                     [40, 50, 60]])
print(array_2d)
# Out:
# [[10 20 30]
#  [40 50 60]]

# %%
array_2d_2 = np.array([[10, -120, 130],
                     [40, -30, 50]])

# %%
array_2d_2 + array_2d
# Out:
# array([[  20, -100,  160],
#        [  80,   20,  110]])

# %%
print("-" * 100)
print(f"Shape (شکل): {array_2d.shape}")
print(f"Size (تعداد کل المان‌ها): {array_2d.size}")
print(f"Dtype (نوع داده): {array_2d.dtype}")
print("-" * 100)
# Out:
# ----------------------------------------------------------------------------------------------------
# Shape (شکل): (2, 3)
# Size (تعداد کل المان‌ها): 6
# Dtype (نوع داده): int64
# ----------------------------------------------------------------------------------------------------

# %% [markdown]
# Create Common Arrays

# %%
zeros_array = np.zeros((3, 4), dtype=np.uint8)
ones_array = np.ones((2, 2)) * 255

# %% [markdown]
# Slicing

# %%
slice_example = array_2d[0, 0:3]
print("--- اسلایس کردن (Slicing) ---")
print(f"سطر اول: {slice_example}")
# انتخاب عنصر در سطر دوم و ستون سوم
print(f"عنصر (1, 2): {array_2d[1, 2]}")
print("-" * 20)
# Out:
# --- اسلایس کردن (Slicing) ---
# سطر اول: [10 20 30]
# عنصر (1, 2): 60
# --------------------

# %% [markdown]
# ### **Matplotlib**

# %%
dummy_image = np.random.randint(0, 256, size=(10, 10), dtype=np.uint8)

# %%
print(dummy_image)
# Out:
# [[191 209 162 172 120  23 139 127 186  77]
#  [182 203  43 236 209 145 209  18  91   7]
#  [ 40 248  20 241 161 232   5  87  41 239]
#  [202   0  29 188 239  62 228 255  61 174]
#  [ 37 153  30  66 158 107  45 108  97 246]
#  [218  78  86 204  25  31 132  65  90 140]
#  [193  83  46  50 203  34 118  83 100  73]
#  [177 113  39  27 179 243 244  57 252  25]
#  [ 97 177 220 221 166 249 161 197 182  93]
#  [154 228  30  34 197  19 100 206 149 103]]

# %%
plt.figure(figsize=(4, 4))
plt.imshow(dummy_image, cmap='gray')
plt.title("NumPy Array Displayed by Matplotlib")
plt.colorbar(label='Pixel Intensity')
plt.show()

# %% [markdown]
# ### **OpenCV**

# %%
image_path = r'images/Lenna.png'

# %%
img = cv2.imread(image_path)

# %%
img.shape
# Out:
# (512, 512, 3)

# %%
plt.figure(figsize=(15, 6))

plt.imshow(img, cmap='grey')
plt.title("Original Image")
plt.axis('off')
# Out:
# (np.float64(-0.5), np.float64(511.5), np.float64(511.5), np.float64(-0.5))

# %%
H, W, C = img.shape

# %%
# 1. Image Slicing (Region of Interest - ROI)
# Select a central 50x50 area of the original image
# Note: H, W were defined in Section 2
start_row = H // 4
end_row = 3 * H // 4
start_col = W // 4
end_col = 3 * W // 4

roi = img[start_row:end_row, start_col:end_col] # Slicing for rows and columns
print(f"ROI Shape: {roi.shape}")
print("-" * 30)
# Out:
# ROI Shape: (256, 256, 3)
# ------------------------------

# %%
R_channel = img[:, :, 0]

red_only_img = img.copy()
red_only_img[:, :, 1] = 0 # Green channel set to zero
red_only_img[:, :, 2] = 0 # Blue channel set to zero
print("Red Channel Max Value:", np.max(R_channel))
# Out:
# Red Channel Max Value: 225

# %%
# 3. Simple Mathematical Operation (Brightness Increase)
# Add a constant value (e.g., 50) to all pixel intensities
# np.clip is used to keep values within the valid range [0, 255]
brightness_increase = np.clip(img.astype(np.int16) + 50, 0, 255).astype(np.uint8)
print("Brightness Increased. Check the displayed image.")
# Out:
# Brightness Increased. Check the displayed image.

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
plt.imshow(roi)
plt.title("ROI (Slicing)")
plt.axis('off')

plt.subplot(1, 3, 2)
plt.imshow(red_only_img)
plt.title("Channel Manipulation (Red Only)")
plt.axis('off')

plt.subplot(1, 3, 3)
plt.imshow(brightness_increase)
plt.title("Mathematical Op. (Brightness +50)")
plt.axis('off')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### **تمارین**

# %% [markdown]
# <div dir="rtl">
# تمرین 1
# : تعاریف
#
#
# <ol>
# <li>dtype</li>
# <li>uint8</li>
# <li>uint16</li>
# <li>انواع cmap ها رو روی یک تصویر greyscale  نمایش بدید</li>
# </ol>
#
# </div>

# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt
import os

img_input= input("enter image path")
img=cv2.imread(img_input)
img.shape
img_org = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_org)
plt.title("Original Image")
# Out:
# enter image path/content/ZTfandiq.jpg
# Text(0.5, 1.0, 'Original Image')

# %%
img_input= input("enter image path")
img=cv2.imread(img_input,0)
print("Original dtype:", img.dtype)
plt.imshow(img)
os.makedirs("results", exist_ok=True)
img_uint16 = np.uint16(img)*256
print("Converted dtype:", img_uint16.dtype)
print("Max value in uint8 image:", img.max())
print("Max value in uint16 image:", img_uint16.max())
plt.figure(figsize=(10,4))

plt.subplot(1,2,1)
plt.imshow(img, cmap='gray')
plt.title("uint8 Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(img_uint16, cmap='gray')
plt.title("uint16 Image")
plt.axis("off")


cmaps = ['gray', 'hot', 'jet', 'bone', 'viridis']

plt.figure(figsize=(12, 6))
for i, cmap in enumerate(cmaps):
    plt.subplot(1, len(cmaps), i+1)
    plt.imshow(img, cmap=cmap)
    plt.title(cmap)
    plt.axis('off')
plot_path = os.path.join("results","cmaps")
plt.savefig(plot_path)
print("The charts were saved in:", plot_path)
plt.show()

print("\n All outputs were placed in the 'results' folder.")
# Out:
# enter image path/content/ZTfandiq.jpg
# Original dtype: uint8
# Converted dtype: uint16
# Max value in uint8 image: 201
# Max value in uint16 image: 51456
# The charts were saved in: results/cmaps
#  All outputs were placed in the 'results' folder.

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# <div dir="rtl">
# تمرین 2
# : برش تصویر و تغییر رنگ به صورت دستی
#
#
# <ol>
# <li>  تصویر را بخوانید</li>
# <li> موقعیت حدودی چشم ها با به دست آورید </li>
# <li> شدت نور در آن قسمت را تقسیم بر 10 کنید  </li>
# <li> تصویر جدید را در کنار تصویر اصلی نمایش دهید </li>
# </ol>
#
# </div>

# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt


img_iput=input("enter image path:")
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(img_rgb)
eye_region = img_rgb[55:70, 110:135]


eye_region_dark = (eye_region / 10).astype(np.uint8)


img_new = img_rgb.copy()
img_new[55:70, 110:135] = eye_region_dark

import matplotlib.pyplot as plt

plt.figure(figsize=(10,5))
plt.subplot(1,2,1)
plt.imshow(img_rgb)
plt.title("Original Image")
plt.axis("off")

plt.subplot(1,2,2)
plt.imshow(img_new)
plt.title("Eye Darkened Image")
plt.axis("off")

plt.show()
# Out:
# enter image path:import matplotlib.pyplot as plt

# %% [markdown]
# <div dir="rtl">
# تمرین 3
#
# ساخت یک تصویر رنگی از سه کانال مجزا
#
#
#
# <ol>
# <li>
#
# ساخت آرایه‌ی پایه: سه آرایه‌ی تک‌بُعدی خاکستری $50 \times 50$ با نام‌های R_arr, G_arr, و B_arr بسازید (با np.zeros یا np.ones یا پر کردن با یک مقدار ثابت)
# <ul>
# <li>R_arr: پر از مقدار ۲۵۵ (قرمز کامل)</li>
# <li>G_arr: پر از مقدار ۱۰۰ (سبز ضعیف)</li>
# <li>B_arr: پر از مقدار ۰ (آبی صفر)</li>
# </ul>
#
# </li>
#
# <li>تغییر سایز: اندازه‌ی هر سه آرایه را به $100 \times 100$ تغییر دهید (مثلاً با Slicing)</li>
# <li>تلفیق (Merge)</li>
# <li>نمایش: تصویر رنگی نهایی را نمایش دهید.</li>
# </ol>
#
#
#
#
# </div>

# %%
import numpy as np
import matplotlib.pyplot as plt


R_arr = np.ones((50,50), dtype=np.uint8) *255
G_arr = np.ones((50,50), dtype=np.uint8) *100
B_arr = np.zeros((50,50), dtype=np.uint8)

R_arr_large = np.repeat(np.repeat(R_arr, 2, axis=0), 2, axis=1)
G_arr_large = np.repeat(np.repeat(G_arr, 2, axis=0), 2, axis=1)
B_arr_large = np.repeat(np.repeat(B_arr, 2, axis=0), 2, axis=1)


img_color = np.stack([R_arr_large, G_arr_large, B_arr_large], axis=2)


plt.imshow(img_color)
plt.title("Custom RGB Image")
plt.axis("off")
plt.show()
